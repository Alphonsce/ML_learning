jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0219.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0220.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0221.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0222.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0223.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0224.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0225.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0226.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0227.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0228.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0229.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0230.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0231.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0232.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0233.jpg
#   inflating: simpsons/train/simpsons_dataset/ned_flanders/pic_0234.jpg
# ...
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0033.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0034.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0035.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0036.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0037.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0038.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0039.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0040.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0041.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0042.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0043.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0044.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0045.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0046.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0047.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0048.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0049.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0050.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0051.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0052.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0053.jpg
#   inflating: simpsons/train/simpsons_dataset/snake_jailbird/pic_0054.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0000.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0001.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0002.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0003.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0004.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0005.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0006.jpg
#   inflating: simpsons/train/simpsons_dataset/troy_mcclure/pic_0007.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0000.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0001.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0002.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0003.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0004.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0005.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0006.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0007.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0008.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0009.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0010.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0011.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0012.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0013.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0014.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0015.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0016.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0017.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0018.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0019.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0020.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0021.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0022.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0023.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0024.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0025.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0026.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0027.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0028.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0029.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0030.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0031.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0032.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0033.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0034.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0035.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0036.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0037.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0038.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0039.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0040.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0041.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0042.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0043.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0044.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0045.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0046.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0047.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0048.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0049.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0050.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0051.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0052.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0053.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0054.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0055.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0056.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0057.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0058.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0059.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0060.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0061.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0062.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0063.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0064.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0065.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0066.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0067.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0068.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0069.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0070.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0071.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0072.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0073.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0074.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0075.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0076.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0077.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0078.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0079.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0080.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0081.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0082.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0083.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0084.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0085.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0086.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0087.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0088.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0089.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0090.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0091.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0092.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0093.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0094.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0095.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0096.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0097.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0098.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0099.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0100.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0101.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0102.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0103.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0104.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0105.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0106.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0107.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0108.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0109.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0110.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0111.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0112.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0113.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0114.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0115.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0116.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0117.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0118.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0119.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0120.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0121.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0122.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0123.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0124.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0125.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0126.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0127.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0128.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0129.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0130.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0131.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0132.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0133.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0134.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0135.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0136.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0137.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0138.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0139.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0140.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0141.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0142.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0143.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0144.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0145.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0146.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0147.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0148.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0149.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0150.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0151.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0152.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0153.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0154.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0155.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0156.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0157.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0158.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0159.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0160.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0161.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0162.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0163.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0164.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0165.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0166.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0167.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0168.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0169.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0170.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0171.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0172.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0173.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0174.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0175.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0176.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0177.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0178.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0179.jpg
#   inflating: simpsons/train/simpsons_dataset/waylon_smithers/pic_0180.jpg

# %%
from torch.utils.data.dataset import ConcatDataset
import pickle
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms, models
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']       # сами объекты датасетов для train и val по своей структуре не будут отличаться, они оба размечены

# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224
DEVICE = torch.device("cuda")

# %%
class SimpsonsDataset(Dataset):
    """
    Класс датасета с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры

    Особенность нашего случая в том, что метки классов содержатся в названиях картинок, а не в
    отдельном цсв файле
    """
    def __init__(self, files, mode, transform=None):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode
        self.transform = transform

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]     # извлекаем все возможные классы из названий картинок
            self.label_encoder.fit(self.labels)     # лейбл энкодер фитим на этих названиях классов

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)     # функция, позволяющая записывать объект в файл
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        ''' По пути к картинке возвращает PIL Image '''
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        # Датасет у нас хранится в виде некоторых картинок, но как только мы достаем из него элемент с ним делается __getitem__
        transform = self.transform
        if transform is None:
            transform = transforms.Compose([
            transforms.ToTensor(),      # кстати totensor приводит итак все величины к от 0 до 1
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # видимо по каждому каналу уже были посчитаны
            ])

        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        # x = np.array(x / 255, dtype='float32')    # это вообще лишнее действие - оно в ToTensor делается, а с np.array плохо трансформации работают
        x = transform(x)
        if self.mode == 'test':
            return x        # если тестовый датасет, то возвращаем чисто тензор нормализованный по каналам
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()

            return x, y     # возвращает элемент датасета в виде нормализованного по каналам торч тензора и его метки
        
    def _prepare_sample(self, image):
        ''' рескейлит PIL Image '''
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return image
        # return image        # гораздо лучше PIL Image возвращать, потому что с ним все трансформации работают

# %%
# for kaggle:

# TRAIN_DIR = Path('../input/journey-springfield/train/simpsons_dataset')
# TEST_DIR = Path('../input/journey-springfield/testset/testset')

# for colab:

TRAIN_DIR = Path('./simpsons/train/simpsons_dataset')
TEST_DIR = Path('./simpsons/testset/testset')

train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))    # рекурсивно собирает все файлы из указанной директории формата jpg
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]

train_files, val_files = train_test_split(train_val_files, test_size=0.25, stratify=train_val_labels)
n_classes = len(np.unique(train_val_labels))

# %%
val_dataset = SimpsonsDataset(val_files, mode='val')
train_dataset = SimpsonsDataset(train_files, mode='train')
test_dataset = SimpsonsDataset(test_files, mode="test")

label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
def fit_epoch(model, train_loader, criterion, optimizer, scheduler):
    '''
    Функция обучения по всем батчам 1 раз (1 эпоха)
    '''
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
    iter = 1
    start_time = time.time()
  
    for inputs, labels in train_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)

        # добавил, чтобы при запуске обучения видеть сколько примерно учиться
        if iter == 5:
            print(f'среднее время на одну итерацию: {round((time.time() - start_time) / 5, 4)}')
        iter += 1

    scheduler.step()
            
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data

    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.no_grad():
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def train(train_data, val_data, model, optimizer, scheduler, epochs, batch_size, save_path='/kaggle/working/model.pth'):
    '''
    Полный цикл обучения
    '''
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, optimizer, scheduler)
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            if epoch != 0:
                if val_acc > history[-1][-1]:      # Если качество на трейне и на валидации выросло, то сохраняем модельку
                    torch.save(model.state_dict(), save_path)

            history.append((train_loss, train_acc, val_loss, val_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
            
    return history

# %%
def predict(model, test_loader):
    ''' Возвращает предсказанные вероятности принадлежности к классу для переданного лоадера '''
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
from sklearn.metrics import f1_score
def get_f1_of_validation(model):

    imgs = [val_dataset[id][0].unsqueeze(0) for id in range(len(val_dataset))]
    probs_ims = predict(model, imgs)        # predict - нам написанная функция (она софтмакс к выходам применяет)
    label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))
    y_pred = np.argmax(probs_ims, -1)

    actual_labels = [val_dataset[id][1] for id in range(len(val_dataset))]
    preds_class = [label_encoder.classes_[i] for i in y_pred]

    return f1_score(actual_labels, y_pred, average='micro')

# %%
import pandas as pd
def make_kaggle_submission(model, test_dataset, output_path='/kaggle/working/my_submission.csv'):
    test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
    probs = predict(model, test_loader)

    preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))   # инверсивно трансформим из цифорок классов в string
    test_filenames = [path.name for path in test_dataset.files]

    my_submit = pd.DataFrame()
    my_submit['Id'] = test_filenames
    my_submit['Expected'] = preds
    my_submit.to_csv(output_path, index=False)

# %%
def plot_history(history):
    '''
    history: list из tuple вида (train_loss, train_acc, val_loss, val_acc) по эпохам
    '''
    loss, acc, val_loss, val_acc = zip(*history)
    
    plt.figure(figsize=(12, 7))
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")

    plt.legend(loc='best')
    plt.xlabel("epochs")
    plt.ylabel("loss")

    plt.show()

# %% [markdown]
# полезная ссылка для fine tune inception v3
# https://discuss.pytorch.org/t/why-auxiliary-logits-set-to-false-in-train-mode/40705

# %% [markdown]
# ---
# снизу пытаюсь разобраться с аугментацией
# ---

# %% [markdown]
# Займусь аугментацией данных, чтобы сделать обучающий датасет побольше, прежде чем обучать какие-то более сложные модели:
#
# - необходимо создать датасет из трансформированных картинок, а потом его конктатенировать с оригинальным датасетом

# %%
from torchvision.utils import save_image

# %% [markdown]
# Код для работы с картинками, чтобы вообще понять: аугментировал я данные или нет

# %%
# Аугментация конечно же применяется только к обучающей выборке:

augm_transf_train = transforms.Compose([                                    
    transforms.RandomHorizontalFlip(p=0.7),
    transforms.RandomResizedCrop(224 ,scale=(0.5, 1)),  # scale - min; max area of crop
    transforms.RandomRotation(25),
    transforms.GaussianBlur(9),     # чем больше ядро - тем суровее блюр очевидно
    # transforms.RandomPerspective(p=0.5),

    # не стоит пока делать преобразований яркости, поскольку тогда надо будет пересчитывать средние и отклонения по каналам
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),                    
])

# %%
train_augm_dataset = SimpsonsDataset(train_files, mode='train', transform=augm_transf_train)

len(train_augm_dataset)
# Out:
# 15699

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %%
img, label = train_augm_dataset[95]
name = label_encoder.inverse_transform(np.array([label]))[0]

imshow(img)
name
# Out:
# 'abraham_grampa_simpson'

# %% [markdown]
# **Сконкатенируем аугментированные данные и обычные данные:**
#
# Думаю можно особо не париться, что картинки между датасетов объединенных не отшаффлены, поскольку даталоадер уже их отшаффлит, когда мы будем оттуда доставать батчи

# %%
new_train_dataset = ConcatDataset(
    [train_dataset, train_augm_dataset]
)       # ну, по сути это просто "объединение" двух классов, здесь нет ничего магического, а то я сначала не особо понял как это возможно

# %% [markdown]
# ---
#
# # Fine tuning EfficientNet на новом датасете
#
# Она состоит из:
# - model._blocks - блоки свертки
# - model._fc - классификатор

# %%
import torch.optim as optim
from torch.optim import lr_scheduler

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (4.1.1)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=27b26386c893c15bc75975d6c0d81697b0315fdda29aea93e00e9564d147be2c
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
from efficientnet_pytorch import EfficientNet

# %%
model_b0 = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b0

# %%
model_b0._blocks[2]
# Out:
# MBConvBlock(
#   (_expand_conv): Conv2dStaticSamePadding(
#     24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_depthwise_conv): Conv2dStaticSamePadding(
#     144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#     (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   )
#   (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_se_reduce): Conv2dStaticSamePadding(
#     144, 6, kernel_size=(1, 1), stride=(1, 1)
#     (static_padding): Identity()
#   )
#   (_se_expand): Conv2dStaticSamePadding(
#     6, 144, kernel_size=(1, 1), stride=(1, 1)
#     (static_padding): Identity()
#   )
#   (_project_conv): Conv2dStaticSamePadding(
#     144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_swish): MemoryEfficientSwish()
# )

# %%
model_b0._fc
# Out:
# Linear(in_features=1280, out_features=1000, bias=True)

# %% [markdown]
# Что ж, займусь настройкой модели:
#
# (Чтобы заморозить целый блок надо итерироваться по model.modules, например это актуально для inception_v3)

# %%
# average pool перед FC слоями не буду замораживать
unfreezed_blocks = 3
for param in model_b0._blocks[:-unfreezed_blocks]:
    param.requires_grad = False
#     print(param.requires_grad)

# num_features -- это размерность вектора фич, поступающего на вход FC-слою

FC_input_size = 1280
model_b0._fc = nn.Sequential(
            nn.Linear(FC_input_size, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, n_classes),
        )

# vgg_model.classifier = nn.Linear(FC_input_size, n_classes)

# %%
model_b0._blocks[10].requires_grad
# Out:
# False

# %%
model_b0.to(DEVICE)
# Out:
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.2, inplace=False)
#   (_fc): Sequential(
#     (0): Linear(in_features=1280, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=1024, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=1024, out_features=42, bias=True)
#   )
#   (_swish): MemoryEfficientSwish()
# )

# %%
# optimizer = optim.Adam(model_b0.parameters(), lr=3e-6, betas=(0.9, 0.999), weight_decay=5e-4)

optimizer = optim.Adam(model_b0.parameters(), lr=1e-4, betas=(0.9, 0.999), weight_decay=5e-4)

exp_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.5)
# lmbda = lambda epoch: 0.8 ** epoch
# scheduler = torch.optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lmbda)

# %%
imshow(new_train_dataset[-100][0])
len(new_train_dataset)
# Out:
# 31398

# %%
history = train(train_data=new_train_dataset,
                val_data=val_dataset,
                model=model_b0,
                epochs=15, batch_size=16,
                scheduler=exp_scheduler, optimizer=optimizer,
                save_path='./gdrive/MyDrive/eff_b0.pth')

# %%
path = './eff_b0.pth'
best_b0_ = model_b0
best_b0_.load_state_dict(torch.load(path))

# %%
plot_history(history)

# %% [markdown]
# Я немножечко лажанул и поэтому у меня сохраняется моделька, которая лучше предыдущей эпохи, а не лучшая по всем эпохам...

# %%
get_f1_of_validation(best_b0_)

# %%
make_kaggle_submission(model_b0, test_dataset, './eff_b0_subm.csv')

# %% [markdown]
# В итоге на kaggle:
#
# **Score: 0.99362**
